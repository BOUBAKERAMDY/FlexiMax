# %%
import pandas as pd
df=pd.read_csv("up00-1a-mobile_home.csv")
print(df)
# Out:
#        upgrade in.ashrae_iecc_climate_zone_2004  \
# 0            0                               1A
# 1            0                               1A
# 2            0                               1A
# 3            0                               1A
# 4            0                               1A
# ...        ...                              ...
# 35035        0                               1A
# 35036        0                               1A
# 35037        0                               1A
# 35038        0                               1A
# 35039        0                               1A
#
#       in.geometry_building_type_recs            timestamp  models_used  \
# 0                        Mobile Home  2018-01-01 00:15:00          183
# 1                        Mobile Home  2018-01-01 00:30:00          183
# 2                        Mobile Home  2018-01-01 00:45:00          183
# 3                        Mobile Home  2018-01-01 01:00:00          183
# ...

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 35040 entries, 0 to 35039
# Data columns (total 79 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   upgrade                                                           35040 non-null  int64
#  1   in.ashrae_iecc_climate_zone_2004                                  35040 non-null  str
#  2   in.geometry_building_type_recs                                    35040 non-null  str
#  3   timestamp                                                         35040 non-null  str
#  4   models_used                                                       35040 non-null  int64
#  5   units_represented                                                 35040 non-null  float64
#  6   out.electricity.ceiling_fan.energy_consumption.kwh                35040 non-null  float64
# ...

# %%
print(df.columns)
# Out:
# Index(['upgrade', 'in.ashrae_iecc_climate_zone_2004',
#        'in.geometry_building_type_recs', 'timestamp', 'models_used',
#        'units_represented',
#        'out.electricity.ceiling_fan.energy_consumption.kwh',
#        'out.electricity.clothes_dryer.energy_consumption.kwh',
#        'out.electricity.clothes_washer.energy_consumption.kwh',
#        'out.electricity.cooling.energy_consumption.kwh',
#        'out.electricity.cooling_fans_pumps.energy_consumption.kwh',
#        'out.electricity.dishwasher.energy_consumption.kwh',
#        'out.electricity.freezer.energy_consumption.kwh',
#        'out.electricity.heating.energy_consumption.kwh',
#        'out.electricity.heating_fans_pumps.energy_consumption.kwh',
#        'out.electricity.heating_hp_bkup.energy_consumption.kwh',
#        'out.electricity.heating_hp_bkup_fa.energy_consumption.kwh',
#        'out.electricity.hot_water.energy_consumption.kwh',
#        'out.electricity.lighting_exterior.energy_consumption.kwh',
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from plotly.offline  import download_plotlyjs,init_notebook_mode,plot, iplot
import cufflinks as cf
init_notebook_mode(connected = True)
cf.go_offline()
# %matplotlib inline

from plotly import tools
import plotly.io as pio
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff
import plotly.offline as offline
# Squarify for treemaps
import squarify
# Random for well, random stuff
import random
# operator for sorting dictionaries
import operator
# For ignoring warnings
import warnings
warnings.filterwarnings('ignore')



df = pd.read_csv("up00-1a-mobile_home.csv")
df.head(2)
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.4.0.min"</script>
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.4.0.min"</script>
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.4.0.min"</script>
# ...

# %%
df.isnull().sum()
# Out:
# upgrade                                                          0
# in.ashrae_iecc_climate_zone_2004                                 0
# in.geometry_building_type_recs                                   0
# timestamp                                                        0
# models_used                                                      0
#                                                                 ..
# out.emissions.all_fuels.lrmer_midcase_25__electricity.co2e_kg    0
# out.emissions.all_fuels.lrmer_midcase_25__fuel_oil.co2e_kg       0
# out.emissions.all_fuels.lrmer_midcase_25__natural_gas.co2e_kg    0
# out.emissions.all_fuels.lrmer_midcase_25__propane.co2e_kg        0
# out.emissions.all_fuels.lrmer_midcase_25.co2e_kg                 0
# Length: 79, dtype: int64

# %%
df.describe(include="all")
# Out:
#         upgrade in.ashrae_iecc_climate_zone_2004  \
# count   35040.0                            35040
# unique      NaN                                1
# top         NaN                               1A
# freq        NaN                            35040
# mean        0.0                              NaN
# std         0.0                              NaN
# min         0.0                              NaN
# 25%         0.0                              NaN
# 50%         0.0                              NaN
# 75%         0.0                              NaN
# max         0.0                              NaN
#
#        in.geometry_building_type_recs            timestamp  models_used  \
# count                           35040                35040      35040.0
# unique                              1                35040          NaN
# top                       Mobile Home  2018-01-01 00:15:00          NaN
# freq                            35040                    1          NaN
# ...

# %%
plt.hist(df["out.electricity.ceiling_fan.energy_consumption.kwh"])
# Out:
# (array([18832.,  5733.,  2783.,  1697.,  2087.,  1578.,  1150.,   476.,
#           537.,   167.]),
#  array([ 82.50263586, 104.55379909, 126.60496231, 148.65612554,
#         170.70728876, 192.75845199, 214.80961521, 236.86077844,
#         258.91194166, 280.96310489, 303.01426812]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(10,6))

sns.histplot(
    df["out.electricity.ceiling_fan.energy_consumption.kwh"],
    bins=30,
    kde=True
)

plt.title("Distribution de la consommation electrique des ventilateurs de plafond", fontsize=16)
plt.xlabel("consommation électrique (kWh)", fontsize=12)
plt.ylabel("Frequence", fontsize=12)

plt.grid(True)
plt.show()
